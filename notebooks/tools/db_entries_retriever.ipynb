# %%
from react_agent.src.agent_tools.database_entries_retriever import DBEntriesRetriever

remote_table_name = "/AIF/T_MVMAPVAL"

db_lookup = DBEntriesRetriever()

output = db_lookup._run(
    table_name=remote_table_name,
)

print(output)
# Out:
# {'mandt': '001', 'ns': '/EDOEG', 'vmapname': 'ISO_TO_EG_UNIT_CODES', 'vmapvalnr': 1, 'extValue': 'Alpha', 'intValue': '14', 'defaultFlag': '', 'sendingSystem': '', 'groupId': '', 'validPeriodNo': '', 'validFrom': '', 'validTo': ''}
# {'mandt': '001', 'ns': '/EDOIN', 'vmapname': 'GSTR_B2CL_INV_AMOUNT', 'vmapvalnr': 1, 'extValue': '250000.00', 'intValue': '', 'defaultFlag': 'X', 'sendingSystem': '', 'groupId': '', 'validPeriodNo': '', 'validFrom': '', 'validTo': ''}
# {'mandt': '001', 'ns': '/EDOKR', 'vmapname': 'ASP_BUSINESS_CODE', 'vmapvalnr': 1, 'extValue': 'up7', 'intValue': '1000000005', 'defaultFlag': '', 'sendingSystem': '', 'groupId': '', 'validPeriodNo': '', 'validFrom': '', 'validTo': ''}
# {'mandt': '001', 'ns': '/EDOKR', 'vmapname': 'ASP_BUSINESS_CODE', 'vmapvalnr': 2, 'extValue': 'urk', 'intValue': '1633669620', 'defaultFlag': '', 'sendingSystem': '', 'groupId': '', 'validPeriodNo': '', 'validFrom': '', 'validTo': ''}
# ...

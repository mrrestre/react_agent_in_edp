# %%
from react_agent.src.agent_tools.source_code_retriever import SourceCodeRetriever

remote_class_name = "cl_edocument_db"

code_lookup = SourceCodeRetriever()

output = code_lookup._run(class_name=remote_class_name)

print(output)
# Out:
# class CL_EDOCUMENT_DB definition  public  create public .public section.  interfaces IF_EDOCUMENT_DB .protected section.  class-data GO_EDOC_CONFIG_DB type ref to CL_EDOC_CONFIG_DB .  class-data GV_ERROR_TXT type STRING .  class-data GS_EDOCOUNTRYTCH type EDOCOUNTRYTCH .  constants GC_OPTIONAL type CHAR1 value 'o' ##NO_TEXT.  methods FORMAT_STATUS_INPUT    importing      !IV_LAND type LAND    changing      !CV_STATUS type EDOC_DOCSTAT .  methods FORMAT_STATUS_OUTPUT    changing      !CV_STATUS type EDOC_DOCSTAT .  methods GET_COUNTRY_SETTINGS    importing      !IV_LAND type LAND    returning      value(RS_EDOCOUNTRYTCH) type EDOCOUNTRYTCH    raising      CX_EDOCUMENT .private section.ENDCLASS.CLASS CL_EDOCUMENT_DB IMPLEMENTATION.METHOD format_status_input.* The format is only relevant if the process manager has been activated for* the country  IF gs_edocountrytch-land IS INITIAL OR    gs_edocountrytch-land <> iv_land.    TRY.        gs_edocountrytch = get_country_settings( iv_land = iv_land ).      CATCH cx_edocument.        CLEAR gs_edocountrytch.        gs_edocountrytch-land = iv_land.    ENDTRY.  ENDIF.  IF gs_edocountrytch-procmgr_is_active = abap_true.   "Process manager active    REPLACE ALL OCCURRENCES OF REGEX '\s' IN cv_status WITH gc_optional.  ENDIF.ENDMETHOD.METHOD format_status_output.  cl_edoc_util=>format_status_output(                       "2550216    CHANGING cv_status = cv_status ).                       "2550216ENDMETHOD.METHOD get_country_settings.  DATA: lv_land_iso TYPE edoc_land.  IF go_edoc_config_db IS NOT BOUND.    CREATE OBJECT go_edoc_config_db.  ENDIF.  CLEAR rs_edocountrytch.  CALL FUNCTION 'COUNTRY_CODE_SAP_TO_ISO'    EXPORTING      sap_code  = iv_land    IMPORTING      iso_code  = lv_land_iso    EXCEPTIONS      not_found = 1      OTHERS    = 2.  IF sy-subrc <> 0.    MESSAGE e881(b1) WITH iv_land INTO gv_error_txt.    cl_edocument=>raise_edoc_exception( ).  ENDIF.  rs_edocountrytch = go_edoc_config_db->if_edoc_config_db~select_edocountrytch( iv_land = lv_land_iso ).  rs_edocountrytch-land = iv_land.ENDMETHOD.  METHOD if_edocument_db~delete_edobupa.                    "2550216    CLEAR rv_retcode.    IF iv_edoc_guid IS NOT INITIAL.      DELETE FROM edobupa WHERE edoc_guid = iv_edoc_guid.    ELSEIF it_edobupa IS NOT initial.      DELETE edobupa FROM TABLE it_edobupa.    ENDIF.    rv_retcode = sy-subrc.  ENDMETHOD.  METHOD if_edocument_db~delete_edocument.    CLEAR rv_retcode.    DELETE FROM edocument WHERE edoc_guid = iv_edoc_guid.    rv_retcode = sy-subrc.  ENDMETHOD.  METHOD if_edocument_db~delete_edocumentref. "new with 2606280    IF iv_update_task EQ abap_false.      CLEAR rv_retcode.      DELETE FROM edocumentref WHERE edoc_guid = iv_edoc_guid.      rv_retcode = sy-subrc.    ELSE.      CALL FUNCTION 'EDOC_DB_DELETE_EDOCUMENTREF' IN UPDATE TASK        EXPORTING          iv_edoc_guid = iv_edoc_guid.    ENDIF.  endmethod.  METHOD if_edocument_db~delete_edosrcfile.    CLEAR rv_retcode.    DELETE FROM edosrcfile WHERE file_guid = iv_file_guid.    rv_retcode = sy-subrc.  ENDMETHOD.  METHOD if_edocument_db~insert_edocontsw.*   2122429 Insert record in EDOCONTSW.    IF iv_update_task EQ abap_false.      INSERT INTO edocontsw VALUES is_edocontsw.      IF sy-subrc NE 0.        MESSAGE e006(edocument) WITH 'EDOCONTSW' INTO gv_error_txt.        cl_edocument=>raise_edoc_exception( ).      ENDIF.    ELSE.      CALL FUNCTION 'EDOC_DB_INSERT_EDOCONTSW' IN UPDATE TASK        EXPORTING          is_edocontsw = is_edocontsw.    ENDIF.  ENDMETHOD.  METHOD if_edocument_db~insert_edocument.*   Insert record in EDOCUMENT. Update task otion added with 2021860    DATA: ls_edocument TYPE edocument.   "2153215*   Start 2153215 - Format field STATUS for input    ls_edocument = is_edocument.    format_status_input( EXPORTING iv_land = ls_edocument-land                         CHANGING  cv_status = ls_edocument-status ).*   End 2153215    IF iv_update_task EQ abap_false.      INSERT INTO edocument VALUES ls_edocument.  "21 ...
